# %% [markdown]
# # **Run Brain Connectome Training on Colab**
#
# <a target="_blank" href="https://colab.research.google.com/github/yourusername/Metric-CNN-BrainConnectome/blob/tiff/notebooks/run_connectome.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# !nvidia-smi
# !python --version
# Out:
# zsh:1: command not found: nvidia-smi
# Python 3.9.19

# %%
#  clone your repo
# !git clone -b tiff https://github.com/yourusername/Metric-CNN-BrainConnectome.git

# Move into repo root
# %cd Metric-CNN-BrainConnectome
# !ls
# Out:
# Cloning into 'Metric-CNN-BrainConnectome'...
# remote: Repository not found.
# fatal: repository 'https://github.com/yourusername/Metric-CNN-BrainConnectome.git/' not found
# [Errno 2] No such file or directory: 'Metric-CNN-BrainConnectome'
# /Users/tiffneyaina/GDA---Brain-connectome/notebooks
# run_connectome.ipynb

# %%
# PyTorch 1.10.2 (no CUDA wheel pin needed – Colab provides CUDA runtime)
# !pip install torch==1.10.2 torchvision==0.11.3 torchaudio==0.10.2

# Exact dependency versions from environment.yml
# !pip install itk==5.2.0 lazy-import==0.2.2 matplotlib==3.3.1 numba==0.55.1 numpy==1.19.5 PyYAML==6.0 scikit-image==0.18.3 SimpleITK==2.2.1 tqdm==4.55.0

# %%
import torch
print(torch.__version__)
print('CUDA available:', torch.cuda.is_available())
print('Device:', torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'CPU')

# %%
# %cd Metric-Cnn-2D-IPMI/Scripts
# !ls *.ipynb
